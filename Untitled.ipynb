# %%
# %run DatasetPrepare.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# L:\Project 3D\DatasetPrepare.py in <module>
#      77 #print ("Running")
#      78 #start = time.time()
# ---> 79 ImageList, JsonList = DatasetPrepare (path_to_dataset, 1024, 1024)
#      80 cv2.imshow ("JsonData", ImageList[count].astype(np.uint8))
#      81 cv2.imshow ("JsonData", JsonList[count].astype(np.uint8)*255)
#
# L:\Project 3D\DatasetPrepare.py in DatasetPrepare(path_to_dataset, height, width)
#      51         for JsonFiles in glob.glob (Folder + "Result\\*"):
#      52             #print (JsonFiles)
# ---> 53             JsonData = ReadJson (JsonFiles)
#      54             #JsonData = numpy.delete (JsonData, 0, 0)
#      55             #JsonData = numpy.delete (JsonData, 0, 1)
#
# L:\Project 3D\DatasetPrepare.py in ReadJson(path_to_json)
#      27     for i in range(len (annotation["shapes"])):
# ...
